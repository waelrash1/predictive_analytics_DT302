# %% [markdown]
# <a href="https://colab.research.google.com/github/waelrash1/predictive_analytics_DT302/blob/main/Linear%2BRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## * Simple Regression

# %%
library(MASS)
### Simple linear regression
names(Boston)
# Out:
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
?Boston

# %%
plot(medv~lstat,Boston)
# Out:
# plot without title

# %%
fit0=lm(medv~1,data=Boston)
fit1=lm(medv~lstat,data=Boston)
fit1

# %%
anova(fit0)
anova(fit1)
anova(fit0,fit1)

# %%
summary(fit1)

# %%
plot(medv~lstat,Boston)
abline(fit1,col="red")

# %%
names(fit1)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"

# %%
confint(fit1)

# %%
predict(fit1,data.frame(lstat=c(5,10,15)),interval="confidence")

# %% [markdown]
# ## * Multiple Regression

# %%
### Multiple linear regression
fit2=lm(medv~lstat+age,data=Boston)
summary(fit2)

# %%
fit3=lm(medv~.,Boston)
summary(fit3)

# %%
par(mfrow=c(2,2))
plot(fit3)

# %%
fit4=update(fit3,~.-age-indus)
summary(fit4)

# %% [markdown]
# ## * non-linear Interaction

# %%
### Nonlinear terms and Interactions
fit5=lm(medv~lstat*age,Boston)
summary(fit5)

# %%
fit6=lm(medv~lstat +I(lstat^2),Boston); summary(fit6)

# %%
attach(Boston)

#plot(1:20,1:20,pch=1:20,cex=2)

# %%
par(mfrow=c(1,1))
plot(medv~lstat)
points(lstat,fitted(fit6),col="red",pch=20)

fit7=lm(medv~poly(lstat,4))
points(lstat,fitted(fit7),col="blue",pch=20)
